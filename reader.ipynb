# %%
import pandas as pd
import csv
import json

# %%
tbl = pd.read_csv('./fnews.csv', encoding='utf-8')

# %%
data = pd.DataFrame()
for d in tbl.data.values[1:]:
    data = data.append(json.loads(d), ignore_index=True)

# %%
data[data.gender != 'none']
# Out:
#               age  evilness gender    score               townSize  \
# 0       18–35 let       1.0    Muž  15135.0    Nad 50 000 obyvatel
# 1       18–35 let       1.0   Žena  16029.0                   none
# 2       18–35 let       1.0    Muž  15160.0    Nad 50 000 obyvatel
# 3       18–35 let       1.0    Muž  15669.0                   none
# 4       18–35 let       1.0    Muž  16042.0    Nad 50 000 obyvatel
# 5       18–35 let       1.0    Muž  15397.0  5 000–50 000 obyvatel
# 6       18–35 let       1.0    Muž  16073.0    Nad 50 000 obyvatel
# 7     Přes 35 let       0.0   Žena  14848.0    Nad 50 000 obyvatel
# 8       18–35 let       0.0    Muž  15156.0    Nad 50 000 obyvatel
# 9       18–35 let       1.0    Muž  15820.0                   none
# 10      18–35 let       0.0   Žena  15322.0    Nad 50 000 obyvatel
# 11    Přes 35 let       1.0    Muž  15864.0                   none
# 12      18–35 let       1.0    Muž  15985.0                   none
# ...
